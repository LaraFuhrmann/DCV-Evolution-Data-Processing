# %%
import pandas as pd
from Bio import SeqIO
import re

# %% [markdown]
# ### Get position of T stretches

# %%
fname_ref_hsv = '../../resources/deletion_analysis/resources/references/hsv.fasta'

fasta_sequences = SeqIO.parse(open(fname_ref_hsv),'fasta')
for item in fasta_sequences:
    ref_hsv = str(item.seq)

# %%
list_T_stretch_start_positions = [i.start() for i in re.finditer("TTTTTT", ref_hsv)]

# %%
def length_of_T_stretch(start_position):
    length_of_T_stretch=0
    for base in ref_hsv[start_position:]: 
        if base =='T':
            length_of_T_stretch+=1
        else: 
            return length_of_T_stretch

# %%
range_T_stretches = [(pos, pos+length_of_T_stretch(pos)) for pos in list_T_stretch_start_positions]

# %%
list_all_T_stretches_pos = []

for T_range in range_T_stretches:
    list_all_T_stretches_pos+=list(range(T_range[0], T_range[1]))

# %%
list_all_T_stretches_pos_one_based = [i +1 for i in list_all_T_stretches_pos]

# %% [markdown]
# ### Load deletions

# %%
# load deletions of HSV sample 
fname_mutations = '../../resources/deletion_analysis/results/deletion_analysis_hsv/all_mutations.csv'

# %%
df = pd.read_csv(fname_mutations)

df['n_reads_var'] = df['Rvar'] + df['Fvar']
df['coverage'] = df['Rtot'] + df['Ftot']
df['frequency'] = df['n_reads_var'] / df['coverage']
df['position'] = df['Pos']

# %%
df[(df['Var']=='-') & (df['Ref']=='T')].to_csv("hsv_T_deletions.csv")

# %% [markdown]
# ### Filter for postions of T strechtes

# %%
# filter for position for TTTTTT
df[df['Pos'].isin(list_all_T_stretches_pos_one_based)]
# Out:
#       Unnamed: 0  Chromosome     Pos Ref Var    Frq1    Frq2    Frq3    Pst1  \
# 3850        3850  MK855052.1   70730   T   G  0.0022       -  0.0067  0.9046
# 5095        5095  MK855052.1   91321   T   C  0.0013  0.0013       -  0.9189
# 6134        6134  MK855052.1  117039   T   A       -  0.0025  0.0021       -
# 6135        6135  MK855052.1  117040   T   C       -  0.0025  0.0021       -
#
#         Pst2  ... Rtot      Pval  Qval         sample    patient     date  \
# 3850       -  ...  390  0.069203   1.0  results_vpipe  munoz2021  hsv2_wt
# 5095  0.9240  ...  997  1.000000   1.0  results_vpipe  munoz2021  hsv2_wt
# 6134  0.9251  ...  375  1.000000   1.0  results_vpipe  munoz2021  hsv2_wt
# 6135  0.9251  ...  373  1.000000   1.0  results_vpipe  munoz2021  hsv2_wt
#
#       n_reads_var coverage frequency position
# 3850            5      781  0.006402    70730
# 5095            2     1630  0.001227    91321
# 6134            1      951  0.001052   117039
# 6135            1      945  0.001058   117040
#
# [4 rows x 24 columns]

# %%
# --> no deletions in those positions

# %% [markdown]
# ### Check coverage in those positions

# %%
# check coverage in those positions

fname_coverage = "coverage.tsv"
df_cov = pd.read_csv(fname_coverage, sep="\t")

# %%
df_cov.shape
# Out:
# (155975, 3)

# %%
len(ref_hsv)
# Out:
# 155975

# %%
df_cov['ref_base'] = list(ref_hsv)
df_cov['pos_one_based'] = df_cov['pos']+1

# %%
# some stats
print('mean: ', df_cov[df_cov['pos'].isin(list_all_T_stretches_pos)]['munoz2021-hsv2_wt'].mean())
print('median: ', df_cov[df_cov['pos'].isin(list_all_T_stretches_pos)]['munoz2021-hsv2_wt'].median())
print('std: ', df_cov[df_cov['pos'].isin(list_all_T_stretches_pos)]['munoz2021-hsv2_wt'].std())
print('max: ', df_cov[df_cov['pos'].isin(list_all_T_stretches_pos)]['munoz2021-hsv2_wt'].max())
print('min: ', df_cov[df_cov['pos'].isin(list_all_T_stretches_pos)]['munoz2021-hsv2_wt'].min())
# Out:
# mean:  607.110655737705
# median:  557.0
# std:  435.29330735158635
# max:  1645
# min:  21

# %% [markdown]
# ### Formatting table for manuscript

# %%
df_cov = df_cov.rename(columns={'ref': 'Reference Genome',
                                'pos_one_based': 'T stretch position',
                                'munoz2021-hsv2_wt': 'Coverage'})
df_cov = df_cov[df_cov['pos'].isin(list_T_stretch_start_positions)]
df_cov = df_cov[['Reference Genome', 'T stretch position', 'Coverage']]

df_cov['T stretch length'] = df_cov['T stretch position'].apply(length_of_T_stretch)
df_cov['T stretch length'] = df_cov['T stretch length']+1

df_cov['Deletion Frequency'] = '0%'

# %%
df_cov
# Out:
#        Reference Genome  T stretch position  Coverage  T stretch length  \
# 9708         MK855052.1                9709       996                 6
# 18500        MK855052.1               18501       887                 6
# 25012        MK855052.1               25013        81                10
# 25917        MK855052.1               25918       742                 6
# 29432        MK855052.1               29433      1382                 6
# 35075        MK855052.1               35076      1056                 6
# 35392        MK855052.1               35393       311                10
# 49044        MK855052.1               49045       252                 6
# 49111        MK855052.1               49112        41                12
# 49117        MK855052.1               49118        24                 6
# 51606        MK855052.1               51607      1160                 6
# 63299        MK855052.1               63300       348                 7
# 63660        MK855052.1               63661       990                 6
# 70729        MK855052.1               70730       781                 7
# 81363        MK855052.1               81364       248                 7
# 91316        MK855052.1               91317      1645                 6
# 93690        MK855052.1               93691       706                 6
# 95611        MK855052.1               95612       439                 6
# 99600        MK855052.1               99601        82                16
# 99606        MK855052.1               99607        52                10
# 99695        MK855052.1               99696       165                 8
# 104059       MK855052.1              104060       560                 6
# 109446       MK855052.1              109447       430                 8
# 112405       MK855052.1              112406      1202                 6
# 117037       MK855052.1              117038       950                 6
# 120244       MK855052.1              120245       673                 6
# 120427       MK855052.1              120428       596                 6
# 121062       MK855052.1              121063       284                 7
# 122083       MK855052.1              122084       152                 7
# 122341       MK855052.1              122342       434                 7
# 128053       MK855052.1              128054       201                 6
# 134937       MK855052.1              134938      1113                 6
# 136104       MK855052.1              136105       858                 6
# 136576       MK855052.1              136577      1288                 6
# 137126       MK855052.1              137127      1023                 6
# 144810       MK855052.1              144811      1029                 6
# 147193       MK855052.1              147194       894                 6
#
#        Deletion Frequency
# 9708                   0%
# 18500                  0%
# 25012                  0%
# 25917                  0%
# 29432                  0%
# 35075                  0%
# 35392                  0%
# 49044                  0%
# 49111                  0%
# 49117                  0%
# 51606                  0%
# 63299                  0%
# 63660                  0%
# 70729                  0%
# 81363                  0%
# 91316                  0%
# 93690                  0%
# 95611                  0%
# 99600                  0%
# 99606                  0%
# 99695                  0%
# 104059                 0%
# 109446                 0%
# 112405                 0%
# 117037                 0%
# 120244                 0%
# 120427                 0%
# 121062                 0%
# 122083                 0%
# 122341                 0%
# 128053                 0%
# 134937                 0%
# 136104                 0%
# 136576                 0%
# 137126                 0%
# 144810                 0%
# 147193                 0%

# %%
df_cov.to_csv('Supplementary_Table_3.csv')
